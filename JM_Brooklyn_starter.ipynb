# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
file = "brooklyn_sales_map.csv"
file_df = pd.read_csv(file)
file_df.head()
# Out:
#    Unnamed: 0  borough      neighborhood building_class_category tax_class  \
# 0           1        3       COBBLE HILL     01 ONE FAMILY HOMES         1
# 1           2        3  BROOKLYN HEIGHTS     01 ONE FAMILY HOMES         1
# 2           3        3        PARK SLOPE     01 ONE FAMILY HOMES         1
# 3           4        3        PARK SLOPE     01 ONE FAMILY HOMES         1
# 4           5        3  BROOKLYN-UNKNOWN     01 ONE FAMILY HOMES         1
#
#    block  lot  easement building_class                address  ... EDesigNum  \
# 0    286   41       NaN             A9     177 PACIFIC STREET  ...       NaN
# 1    237   57       NaN             A9        27 MONROE PLACE  ...       NaN
# 2   1072   50       NaN             A9    45 MONTGOMERY PLACE  ...       NaN
# 3   1068   44       NaN             A9  17 PROSPECT PARK WEST  ...       NaN
# 4   7576    6       NaN             A9          3009 AVENUE I  ...       NaN
#
# ...

# %%
building_area = file_df[['building_class_category','sale_price','gross_sqft']]
building_area
# Out:
#       building_class_category  sale_price  gross_sqft
# 0         01 ONE FAMILY HOMES  15500000.0       10000
# 1         01 ONE FAMILY HOMES  12900000.0        7371
# 2         01 ONE FAMILY HOMES  12600000.0        5730
# 3         01 ONE FAMILY HOMES  12400000.0        5243
# 4         01 ONE FAMILY HOMES  11500000.0        1344
# ...                       ...         ...         ...
# 54200     01 ONE FAMILY HOMES    385000.0        1224
# 54201     01 ONE FAMILY HOMES    428000.0        1224
# 54202     01 ONE FAMILY HOMES    640000.0        3480
# 54203     01 ONE FAMILY HOMES    225000.0        2500
# 54204     01 ONE FAMILY HOMES         0.0        1485
#
# [54205 rows x 3 columns]

# %%
x_axis = building_area['gross_sqft']
y_axis = building_area['sale_price']
plt.xlabel('Sq Ft')
plt.ylabel('Sale Price')
plt.title('Correlation between building size and sale price')
plt.scatter(x_axis,y_axis,marker = 'o',facecolor = 'red',edgecolor = 'black',alpha = 0.75)
