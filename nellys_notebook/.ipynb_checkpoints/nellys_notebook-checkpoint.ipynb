# %%
import matplotlib.pyplot as plt
import pandas as pd
#from config import (api_key, gkey)
#import gmaps

# %%
brooklyn_housing_data = "../nellys_raw_data/brooklyn_sales_map.csv"
housing_data = pd.read_csv(brooklyn_housing_data)
housing_data_df = pd.DataFrame(housing_data)
housing_data_df_clean = housing_data_df.rename(columns={'year_of_sale': 'Years',
                                                       'neighborhood': 'Neighborhoods'})
housing_data_df_clean.head()
# Out:
# //anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (10,40,86) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  borough     Neighborhoods building_class_category tax_class  \
# 0         577        3       COBBLE HILL     01 ONE FAMILY HOMES         1
# 1         758        3  BROOKLYN HEIGHTS     01 ONE FAMILY HOMES         1
# 2         781        3        PARK SLOPE     01 ONE FAMILY HOMES         1
# 3         799        3        PARK SLOPE     01 ONE FAMILY HOMES         1
# 4         868        3  BROOKLYN-UNKNOWN     01 ONE FAMILY HOMES         1
#
#    block  lot  easement building_class                address  ... EDesigNum  \
# 0    286   41       NaN             A9     177 PACIFIC STREET  ...       NaN
# 1    237   57       NaN             A9        27 MONROE PLACE  ...       NaN
# 2   1072   50       NaN             A9    45 MONTGOMERY PLACE  ...       NaN
# 3   1068   44       NaN             A9  17 PROSPECT PARK WEST  ...       NaN
# 4   7576    6       NaN             A9          3009 AVENUE I  ...       NaN
#
#    APPBBL  APPDate  PLUTOMapID  FIRM07_FLA  PFIRM15_FL  Version  MAPPLUTO_F  \
# 0     0.0      NaN         1.0         NaN         NaN   17V1.1         0.0
# 1     0.0      NaN         1.0         NaN         NaN   17V1.1         0.0
# 2     0.0      NaN         1.0         NaN         NaN   17V1.1         0.0
# 3     0.0      NaN         1.0         NaN         NaN   17V1.1         0.0
# 4     NaN      NaN         NaN         NaN         NaN      NaN         NaN
#
#    SHAPE_Leng   SHAPE_Area
# 0  256.846770  2765.347371
# 1  252.805294  2453.650745
# 2  240.859327  2819.690204
# 3  252.435080  2668.772380
# 4         NaN          NaN
#
# [5 rows x 111 columns]

# %%
total_neighborhoods = housing_data_df_clean.groupby(['Years',
                                            'Neighborhoods'])
#total_neighborhoods.head()

number_of_sales = total_neighborhoods['sale_price'].count()
#number_of_sales

avg_sale_price = total_neighborhoods['sale_price'].mean()
#avg_sale_price

neighborhood_data = {'Total Number of Sales by Neighborhood': number_of_sales,
                       'Average Sale Price by Neighborhood': avg_sale_price}
#neighborhood_data

neighborhood_summary = pd.DataFrame(neighborhood_data)
#neighborhood_summary

final_neighborhood_summary = neighborhood_summary.copy()
final_neighborhood_summary['Average Sale Price by Neighborhood'] = final_neighborhood_summary['Average Sale Price by Neighborhood'].map('${:,.0f}'.format)
final_neighborhood_summary.head()
# Out:
#                           Total Number of Sales by Neighborhood  \
# Years Neighborhoods
# 2003  BATH BEACH                                             46
#       BAY RIDGE                                             238
#       BEDFORD STUYVESANT                                    131
#       BENSONHURST                                            95
#       BERGEN BEACH                                           68
#
#                          Average Sale Price by Neighborhood
# Years Neighborhoods
# 2003  BATH BEACH                                   $275,425
#       BAY RIDGE                                    $342,223
#       BEDFORD STUYVESANT                           $157,160
#       BENSONHURST                                  $230,688
#       BERGEN BEACH                                 $326,251

# %%
final_neighborhood_summary.unstack()
final_neighborhood_summary.unstack(level=0).head()
# Out:
#                    Total Number of Sales by Neighborhood                       \
# Years                                               2003   2004   2005   2006
# Neighborhoods
# BATH BEACH                                          46.0   44.0   49.0   34.0
# BAY RIDGE                                          238.0  218.0  244.0  168.0
# BEDFORD STUYVESANT                                 131.0  142.0  156.0  105.0
# BENSONHURST                                         95.0   88.0   93.0  105.0
# BERGEN BEACH                                        68.0   98.0  154.0   74.0
#
#                                                               ...  \
# Years                2007   2008   2009   2010   2011   2012  ...
# Neighborhoods                                                 ...
# BATH BEACH           31.0   26.0   33.0   33.0   26.0   29.0  ...
# BAY RIDGE           219.0  159.0  176.0  166.0  146.0  168.0  ...
# BEDFORD STUYVESANT   89.0   61.0   34.0   44.0   43.0   59.0  ...
# BENSONHURST          90.0   62.0   57.0   68.0   62.0   78.0  ...
# BERGEN BEACH         63.0   45.0   51.0   51.0   50.0   41.0  ...
#
#                    Average Sale Price by Neighborhood                      \
# Years                                            2008      2009      2010
# Neighborhoods
# BATH BEACH                                   $379,385  $332,965  $280,650
# BAY RIDGE                                    $484,539  $421,656  $489,157
# BEDFORD STUYVESANT                           $250,991  $280,169  $172,131
# BENSONHURST                                  $333,015  $333,465  $429,875
# BERGEN BEACH                                 $507,050  $493,936  $380,070
#
#                                                                       \
# Years                   2011      2012      2013      2014      2015
# Neighborhoods
# BATH BEACH          $271,635  $364,310  $508,333  $497,107  $617,121
# BAY RIDGE           $464,939  $477,447  $533,660  $607,823  $672,582
# BEDFORD STUYVESANT  $217,035  $317,770  $340,017  $486,681  $596,757
# BENSONHURST         $349,089  $334,628  $400,312  $385,963  $508,007
# BERGEN BEACH        $409,815  $273,309  $356,132  $361,609  $401,625
#
#
# Years                   2016      2017
# Neighborhoods
# BATH BEACH          $530,917  $641,209
# BAY RIDGE           $697,643  $756,157
# BEDFORD STUYVESANT  $446,503  $516,854
# BENSONHURST         $550,742  $563,060
# BERGEN BEACH        $408,447  $475,032
#
# [5 rows x 30 columns]

# %%
ax = final_neighborhood_summary.unstack(level=0).plot (figsize = (30,15), legend = True)
#ax.set_prop_cycle(None)

# %%
#gmaps.configure(api_key=gkey)

#fig = gmaps.figure()

#heat_layer = gmaps.heatmap_layer(housing_data_df_clean['Neighborhoods'], weights= housing_data_df_clean['sale_price'], dissipating=False, max_intensity=100, point_radius = 1)

#heat_layer.dissipating = False
#heat_layer.max_intensity = 100
#heat_layer.point_radius = 1

#fig.add_layer(heat_layer)

#fig
# Out:
#   File "<ipython-input-5-807c369ff51d>", line 6
#     dissipating=False, max_intensity=100,
#     ^
# IndentationError: unexpected indent
