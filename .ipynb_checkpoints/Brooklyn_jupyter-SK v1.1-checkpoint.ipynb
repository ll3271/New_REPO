# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# %%
file = "brooklyn_sales_map.csv"
file_df = pd.read_csv(file)
file_df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (40,41,43,45,46,47,86) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  borough           neighborhood building_class_category  \
# 0           1        3     DOWNTOWN-METROTECH   28  COMMERCIAL CONDOS
# 1           2        3  DOWNTOWN-FULTON FERRY  29  COMMERCIAL GARAGES
# 2           3        3       BROOKLYN HEIGHTS    21  OFFICE BUILDINGS
# 3           4        3             MILL BASIN     22  STORE BUILDINGS
# 4           5        3       BROOKLYN HEIGHTS         26 OTHER HOTELS
#
#   tax_class  block   lot  easement building_class              address  ...  \
# 0         4    140  1001       NaN             R5       330 JAY STREET  ...
# 1         4     54     1       NaN             G7        85 JAY STREET  ...
# 2         4    204     1       NaN             O6  29 COLUMBIA HEIGHTS  ...
# 3         4   8470    55       NaN             K6        5120 AVENUE U  ...
# 4         4    230     1       NaN             H8      21 CLARK STREET  ...
#
#   EDesigNum        APPBBL     APPDate  PLUTOMapID  FIRM07_FLA  PFIRM15_FL  \
# 0       NaN           NaN         NaN         NaN         NaN         NaN
# 1       NaN  3.000540e+09  12/06/2002         1.0         NaN         NaN
# 2       NaN  0.000000e+00         NaN         1.0         NaN         NaN
# 3       NaN  0.000000e+00         NaN         1.0         1.0         1.0
# 4       NaN  0.000000e+00         NaN         1.0         NaN         NaN
#
#    Version  MAPPLUTO_F   SHAPE_Leng     SHAPE_Area
# 0      NaN         NaN          NaN            NaN
# 1   17V1.1         0.0  1559.889144  140131.577176
# 2   17V1.1         0.0   890.718521   34656.447240
# 3   17V1.1         0.0  3729.786857  797554.847834
# 4   17V1.1         0.0   620.761169   21360.147631
#
# [5 rows x 111 columns]

# %%
file_df.columns[0:20]
# Out:
# Index(['Unnamed: 0', 'borough', 'neighborhood', 'building_class_category',
#        'tax_class', 'block', 'lot', 'easement', 'building_class', 'address',
#        'apartment_number', 'zip_code', 'residential_units', 'commercial_units',
#        'total_units', 'land_sqft', 'gross_sqft', 'year_built',
#        'tax_class_at_sale', 'building_class_at_sale'],
#       dtype='object')

# %%
bk_master = file_df[['Unnamed: 0', 'building_class_category','sale_price','gross_sqft',
                     'year_of_sale','year_built', "ZipCode", 'neighborhood','residential_units', 'SchoolDist',
                     'BldgClass', 'YearAlter1', 'YearAlter2', 'LotArea','ResArea', 'UnitsRes', 'NumFloors',  
                    ]]
bk_master.head()
# Out:
#    Unnamed: 0 building_class_category   sale_price  gross_sqft  year_of_sale  \
# 0           1   28  COMMERCIAL CONDOS  499401179.0         0.0          2008
# 1           2  29  COMMERCIAL GARAGES  345000000.0         0.0          2016
# 2           3    21  OFFICE BUILDINGS  340000000.0    304650.0          2016
# 3           4     22  STORE BUILDINGS  276947000.0   2548000.0          2012
# 4           5         26 OTHER HOTELS  202500000.0    356000.0          2017
#
#    year_built  ZipCode           neighborhood  residential_units  SchoolDist  \
# 0        2002      NaN     DOWNTOWN-METROTECH                  0         NaN
# 1           0  11201.0  DOWNTOWN-FULTON FERRY                  0        13.0
# 2        1924  11201.0       BROOKLYN HEIGHTS                  0        13.0
# 3        1970  11234.0             MILL BASIN                  0        22.0
# 4        1927  11201.0       BROOKLYN HEIGHTS                  0        13.0
#
#   BldgClass  YearAlter1  YearAlter2   LotArea  ResArea  UnitsRes  NumFloors
# 0       NaN         NaN         NaN       NaN      NaN       NaN        NaN
# 1        G7         0.0         0.0  134988.0      0.0       0.0        0.0
# 2        O6      1980.0         0.0   32000.0      0.0       0.0       13.0
# 3        K6         0.0         0.0  905000.0      0.0       0.0        2.0
# 4        H8      1998.0      2000.0   20267.0      0.0       0.0       15.0

# %%
# Master csv filtered for one family homes
one_fam_master = bk_master.loc[bk_master["building_class_category"] == "01 ONE FAMILY HOMES",:] 
print(len(one_fam_master))
one_fam_master.head()
# Out:
# 54205
#      Unnamed: 0 building_class_category  sale_price  gross_sqft  year_of_sale  \
# 576         577     01 ONE FAMILY HOMES  15500000.0     10000.0          2015
# 757         758     01 ONE FAMILY HOMES  12900000.0      7371.0          2017
# 780         781     01 ONE FAMILY HOMES  12600000.0      5730.0          2017
# 798         799     01 ONE FAMILY HOMES  12400000.0      5243.0          2015
# 867         868     01 ONE FAMILY HOMES  11500000.0      1344.0          2015
#
#      year_built  ZipCode      neighborhood  residential_units  SchoolDist  \
# 576        1931  11201.0       COBBLE HILL                  1        15.0
# 757        1844  11201.0  BROOKLYN HEIGHTS                  1        13.0
# 780        1901  11215.0        PARK SLOPE                  1        15.0
# 798        1899  11215.0        PARK SLOPE                  1        15.0
# 867        1925      NaN  BROOKLYN-UNKNOWN                  1         NaN
#
#     BldgClass  YearAlter1  YearAlter2  LotArea  ResArea  UnitsRes  NumFloors
# 576        A9         0.0         0.0   2513.0   7500.0       1.0        3.0
# 757        A9         0.0         0.0   2500.0   7371.0       1.0        4.0
# 780        A9      2009.0         0.0   2697.0   5730.0       1.0        3.0
# 798        A9         0.0         0.0   2500.0   5243.0       1.0        3.5
# 867       NaN         NaN         NaN      NaN      NaN       NaN        NaN

# %%
one_fam_master.dtypes
# Out:
# Unnamed: 0                   int64
# building_class_category     object
# sale_price                 float64
# gross_sqft                 float64
# year_of_sale                 int64
# year_built                   int64
# ZipCode                    float64
# neighborhood                object
# residential_units            int64
# SchoolDist                 float64
# BldgClass                   object
# YearAlter1                 float64
# YearAlter2                 float64
# LotArea                    float64
# ResArea                    float64
# UnitsRes                   float64
# NumFloors                  float64
# dtype: object

# %%
#One Family Master filtered for three years data
one_fam_3years = one_fam_master.loc[(one_fam_master["year_of_sale"] == 2015  )|
                                    (one_fam_master["year_of_sale"] == 2016  )|
                                    (one_fam_master["year_of_sale"] == 2017  ) ,:]

one_fam_3years = one_fam_3years.loc[(one_fam_3years["sale_price"]<5000000)&
                                    (one_fam_3years["sale_price"] > 100000)& 
                                    (one_fam_3years["gross_sqft"] < 5000)& 
                                    (one_fam_3years["gross_sqft"] > 100)& 
                                    (one_fam_3years["year_built"] > 1890)
                                    ,:]
one_fam_3years["SP/Sq_ft"] = one_fam_3years["sale_price"] / one_fam_3years["gross_sqft"]
print(len(one_fam_3years))
one_fam_3years.head()
# Out:
# 6540
#       Unnamed: 0 building_class_category  sale_price  gross_sqft  \
# 2535        2536     01 ONE FAMILY HOMES   4980000.0      4100.0
# 2547        2548     01 ONE FAMILY HOMES   4950000.0      4368.0
# 2557        2558     01 ONE FAMILY HOMES   4900620.0      2630.0
# 2576        2577     01 ONE FAMILY HOMES   4900000.0      3904.0
# 2578        2579     01 ONE FAMILY HOMES   4900000.0      2200.0
#
#       year_of_sale  year_built  ZipCode      neighborhood  residential_units  \
# 2535          2015        2014  11201.0       BOERUM HILL                  1
# 2547          2016        1901  11215.0        PARK SLOPE                  1
# 2557          2016        1901  11215.0        PARK SLOPE                  1
# 2576          2016        1901  11215.0        PARK SLOPE                  1
# 2578          2017        1901  11201.0  BROOKLYN HEIGHTS                  1
#
#       SchoolDist BldgClass  YearAlter1  YearAlter2  LotArea  ResArea  \
# 2535        15.0        A4      2013.0         0.0   1200.0   4100.0
# 2547        15.0        A4         0.0         0.0   1875.0   3276.0
# 2557        15.0        A4         0.0         0.0   1501.0   2630.0
# 2576        15.0        A4      2006.0         0.0   1950.0   2888.0
# 2578        13.0        A5      1995.0         0.0   2550.0   2200.0
#
#       UnitsRes  NumFloors     SP/Sq_ft
# 2535       1.0        4.0  1214.634146
# 2547       1.0        3.0  1133.241758
# 2557       1.0        3.0  1863.353612
# 2576       1.0        3.0  1255.122951
# 2578       1.0        2.0  2227.272727

# %%
# Sale Price vs Area
N = len(one_fam_3years)
x = one_fam_3years['gross_sqft']
y = one_fam_3years['sale_price']
colors = ("blue")
area = np.pi*15

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Sale Price vs Area (sq-ft)')
plt.xlabel('gross_sqft')
plt.ylabel('Sale Price')
plt.show()

# %%
# Sale Price vs Year Built
N = len(one_fam_3years)
x = one_fam_3years['year_built']
y = one_fam_3years['sale_price']
colors = ("blue")
area = np.pi*15

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Sale Price vs Year Built')
plt.xlabel('Year Built')
plt.ylabel('Sale Price')
plt.show()

# %%
# Sale Price vs Year Built
N = len(one_fam_3years)
x = one_fam_3years['year_built']
y = one_fam_3years['SP/Sq_ft']
colors = ("blue")
area = np.pi*15

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('SP/Sq_ft vs Year Built')
plt.xlabel('Year Built')
plt.ylabel('SP/Sq_ft')
plt.show()

# %%
# Sale Price vs Area
N = len(one_fam_3years)
x = one_fam_3years['ZipCode']
y = one_fam_3years['sale_price']
colors = ("blue")
area = np.pi*15

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Sale Price vs ZipCode')
plt.xlabel('ZipCode')
plt.ylabel('Sale Price')
plt.show()

# %%
# Sale Price vs Area
N = len(one_fam_3years)
x = one_fam_3years['ZipCode']
y = one_fam_3years['SP/Sq_ft']
colors = ("blue")
area = np.pi*15

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('SP per Sq.ft vs ZipCode')
plt.xlabel('ZipCode')
plt.ylabel('SP per Sq.ft')
plt.show()
